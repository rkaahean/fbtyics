# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
from unidecode import unidecode
import seaborn as sns
import warnings
from matplotlib.font_manager import FontProperties


# %matplotlib notebook
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Getting a List of All Right Backs

# %%
df = pd.read_table('RB.txt', skiprows = 0, header = None)
df = df.fillna(axis = 'index', method = 'ffill')
df = df.drop_duplicates(subset = 0, keep = 'last')

# %%
chng = {
    0 : 'Player',
    1:'Country',
    5:'Age',
    7:'Club'
}

cols = list(chng.values())

# %%
df = df.rename(axis = 'columns', mapper = chng)[cols]
df.to_csv('RB2019.csv')

# %%
#If you want more, start from the next page of 
# https://www.fifaindex.com/players/8/?position=3&order=desc
# and paste it into RB.txt

# %% [markdown]
# ## Getting and Cleaning the Statistics

# %%
stats = pd.read_csv('RBStats2019.csv')
stats = stats.set_index('Player Name')

# %%
fdf = df.join(stats, on = 'Player')

# %% [markdown]
# Need to Convert the foreign characters to english

# %%
names = df['Player'].values

#Decoding and concerting to plain text, and having dictionaries to convert between
plydict = {i: unidecode(i) for i in names}
realdict = {unidecode(i): i for i in names}
df['Player'] = list(plydict.values())

# %% [markdown]
# Mapping Single Named Players with Two Names

# %%
#All the Players who are there in the stats dataset but NOT in Right Back Dataset
missing = fdf['Team'].isna()

#All the players in the stats dataset
substr_list = stats.index.values.astype('str')

#All Player in RB dataset
names = list(plydict.values())

# %%
conv = {}

#For all players in the stats dataset
for i in substr_list:
    
    #Get Last Name
    s = i.split()[-1]
    
    #For all player in the RB Dataset
    for x in names:
        
        if x == s:
            conv[x] = i

# %%
df['Player'] = df['Player'].replace(conv)
fdf = df.join(stats, on = 'Player')

# %% [markdown]
# Getting Players with data only

# %%
missing = fdf['Team'].isna()
fdf = fdf[~missing]

# %% [markdown]
# Combining league and UCL data

# %%
fdf.columns
# Out:
# Index(['Player', 'Country', 'Age', 'Club', 'Team', 'League', 'POS', 'GP',
#        'MIN', 'Y', 'YR', 'R', 'A', 'SA', 'CR', 'ACR', 'CC', 'FS', 'P', 'AP',
#        'ACRO', 'BCC', 'DR', 'APW', 'TBOX', 'ECL'],
#       dtype='object')

# %%
cols = [
    'Player', 'Country', 'Age', 'Club','MIN',
    
    #Attacking Stats
    'A',
    #'SA',
    'ACR',
    'FS',
    'CR',
    'AP',
    'ACRO',
    'CC',
    'P',
    #'BCC',
    'DR',
    #'APW',
    'TBOX'
]


adf = fdf.groupby(cols[:4])[cols[4:]].sum()

#Greater than 900 Minutes
logic = adf['MIN'] > 900
adf = adf[logic]


#Crossing %
acc_crosses = adf['ACR'] + adf['ACRO']
crosses = adf['CR']
adf['CRrat'] = (acc_crosses/crosses) * acc_crosses
cols = cols + ['CRrat']

#Passing %
adf['P%'] = (adf['P']/adf['AP']) * 100
cols = cols + ['P%']


original_df = adf.copy()

rm =['CR', 'ACR', 'ACRO', 'AP', 'P']
for i in rm:
    cols.remove(i)


adf = adf.reset_index()
adf = adf[cols]

# %%
cols[6:-1]
# Out:
# ['FS', 'CC', 'DR', 'TBOX', 'CRrat']

# %%
adf.columns
# Out:
# Index(['Player', 'Country', 'Age', 'Club', 'MIN', 'A', 'FS', 'CC', 'DR',
#        'TBOX', 'CRrat', 'P%'],
#       dtype='object')

# %%
adf.sort_values(by = 'DR', ascending=False).head(10)
# Out:
#                 Player   Country   Age             Club     MIN     A    FS  \
# 130        Youcef Atal   Algeria  22.0         OGC Nice  2171.0   0.0  58.0
# 26    Daniel Caligiuri     Italy  31.0          Schalke  3362.0   3.0  44.0
# 58        Joao Cancelo  Portugal  24.0         Juventus  2446.0   5.0  33.0
# 100    Ricardo Pereira  Portugal  25.0   Leicester City  3125.0   6.0  48.0
# 104         Ruben Pena     Spain  27.0         SD Eibar  2673.0   2.0  34.0
# 0    Aaron Wan-Bissaka   England  21.0   Crystal Palace  3135.0   3.0  16.0
# 17          Bouna Sarr    France  27.0               OM  2244.0   1.0  32.0
# 28              Danilo    Brazil  27.0  Manchester City  6324.0   0.0  75.0
# 1        Achraf Hakimi   Morocco  20.0         Dortmund  2110.0   7.0  44.0
# 65      Joshua Kimmich   Germany  24.0        FC Bayern  3690.0  15.0  66.0
#
#        CC    DR  TBOX      CRrat         P%
# 130  22.0  96.0  95.0   5.157143  82.944915
# 26   69.0  74.0  77.0  19.380734  69.393718
# 58   42.0  71.0  57.0  24.801527  85.296075
# 100  33.0  68.0  79.0   8.653846  78.016960
# 104  44.0  62.0  37.0  46.296296  71.460341
# 0    14.0  61.0  30.0  10.285714  73.047210
# 17   30.0  55.0  30.0  20.644860  85.174954
# 28   31.0  51.0  69.0   9.333333  83.170872
# 1    17.0  43.0  45.0   4.654545  85.858586
# 65   98.0  40.0  67.0  41.953177  90.420561

# %% [markdown]
# ## Interpreting the Data

# %%
reqs = [
    'Player',
    'Club',
    'Country',
    'MIN',
    'Age'
]

def per90(df1 ,df2, x):
    for i in x:
        df1[i + '90'] = df2[i]/df2['MIN'] * 90
        
    return df1

def sum_vals(d):
    n = len(sts90)
    sm = 0
    for i in range(n):
        wt = d[i]/mxs[i]
        sm = sm + wt * d[i]
    return sm

def sum_wts(d):
    n = len(sts90)
    sm = 0
    for i in range(n):
        wt = d[i]/mxs[i]
        sm = sm + wt
    return sm



df = adf[reqs]
sts = cols[6: -1]
sts90 = [i + '90' for i in sts]

#Convert to per 90 stats
df = per90(df, adf, sts)

mxs = [df[i].max() for i in sts90]

#Get Sum of Values, and Sum of their weights
df['SumVal'] = df[sts90].apply(sum_vals, axis = 1)
df['SumWt'] = df[sts90].apply(sum_wts, axis = 1)

# %%
#Include only players who have played certion number of minutes

logic = (df['MIN'] > 900) & (df['Age'] < 29.0)
xdf = df[logic]

# %%
xdf = xdf.sort_values(by = 'SumVal', ascending=False)
xdf.head()
# Out:
#                Player         Club   Country     MIN   Age      FS90  \
# 130       Youcef Atal     OGC Nice   Algeria  2171.0  22.0  2.404422
# 6    Alvaro Odriozola  Real Madrid     Spain  1406.0  23.0  1.344239
# 58       Joao Cancelo     Juventus  Portugal  2446.0  24.0  1.214227
# 65     Joshua Kimmich    FC Bayern   Germany  3690.0  24.0  1.609756
# 71    Kieran Trippier        Spurs   England  2814.0  28.0  0.895522
#
#          CC90      DR90    TBOX90   CRrat90     SumVal     SumWt
# 130  0.912022  3.979733  3.938277  0.213792  10.105677  3.233009
# 6    1.344239  0.576102  3.520626  0.618167   4.724676  2.298110
# 58   1.545380  2.612428  2.097302  0.912566   4.664008  2.622088
# 65   2.390244  0.975610  1.634146  1.023248   4.587037  2.620190
# 71   2.302772  0.287846  1.119403  1.626065   3.981728  2.322464

# %%
#Dropping Certain Players

xdf = xdf.drop(130, axis = 'index')
xdf = xdf.drop(64, axis = 'index')
xdf = xdf.drop(96, axis = 'index')

# %%
for i in sts90:
    print(i, len(xdf[xdf[i] == 0]))
# Out:
# FS90 0
# CC90 0
# DR90 0
# TBOX90 0
# CRrat90 2

# %% [markdown]
# ## Visalizing Data

# %%
#How many players you want
vdf = xdf.iloc[:30]
vdf.head()

ixs = vdf.index

# %%
vdf.columns
# Out:
# Index(['Player', 'Club', 'Country', 'MIN', 'Age', 'FS90', 'CC90', 'DR90',
#        'TBOX90', 'CRrat90', 'SumVal', 'SumWt'],
#       dtype='object')

# %%
sns.set()

fig = plt.figure(figsize = (12.5, 12.5))


vdf = vdf.sort_values(by = 'SumWt', ascending=True)
n = vdf['Player'].values

ixs = vdf.index
x = vdf['SumWt'].values
y = vdf['SumVal'].values

#sz = vdf['P%'].values
sz = adf.iloc[ixs]['A'].values + 8

hfont = {'fontname':'Helvetica'}
config = {
    'ha': 'center', 
    'va': 'center'
}

for i, txt in enumerate(n):
    if i != 0:
        disx = x[i] - x[i-1]
        if disx > 0.0001:
            plt.scatter(x[i], y[i], c = 'r', s= (1.25)**sz[i])
            plt.text(x[i], y[i]+ 0.038, txt,config,  fontsize = 10, rotation = 0, family = 'MS Gothic')
    else:
        plt.scatter(x[i], y[i], c = 'r', s= (1.25)**sz[i])
        plt.text(x[i], y[i]+ 0.038, txt, config,  fontsize = 10, rotation = 0, family = 'MS Gothic')

plt.arrow(2.48, 2.4, 0.12, 0, width = 0.03, head_length = 0.03, color = 'black')
plt.text(2.41, 2.45, "Increasing Offensive Traits", fontsize = 13, family = "Franklin Gothic Medium")

plt.arrow(1.55, 4.3, 0, 0.3, width = 0.01, head_length = 0.08, color = 'black' )
plt.text(1.57, 4.5, "Increasing Offensive\n Performances", fontsize = 13, family = "Franklin Gothic Medium")


plt.gcf().text(1.0, 0.01, "HI", fontsize=14, color = 'black')


fig = plt.gcf()
ax = plt.gca()
ax.set_xlabel('Attacking Traits', family = "Impact", fontsize = 13)
ax.set_ylabel('Attacking Output', family = "Impact", fontsize = 13)


ax.set_title('Best Offensive Right Backs in Top 5 Leagues (Minimum 900 Minutes)', family = 'Impact', fontsize = 19)
fig.savefig('rb.jpg', dpi = 500)
# Out:
# <img src="data:image/png;base64,..." width="1249.6">

# %% [markdown]
# ## Provide Ranking System

# %%
xdf.set_index('Player').loc['Diogo Dalot']
# Out:
# Club       Manchester Utd
# Country          Portugal
# MIN                  1257
# Age                    20
# FS90             0.143198
# CC90              1.28878
# DR90              1.14558
# TBOX90            1.64678
# CRrat90           1.46181
# SumVal            2.66677
# SumWt             1.93812
# Name: Diogo Dalot, dtype: object

# %%
def get_ranks(df, sts90):
    for i in sts90:
        df[i + ' Rank'] = df[i].rank(ascending = False)
        
    return df
t = get_ranks(xdf, sts90)

# %%
sts90
# Out:
# ['FS90', 'CC90', 'DR90', 'TBOX90', 'CRrat90']

# %%
t.set_index('Player').loc['Joshua Kimmich']
# Out:
# Club            FC Bayern
# Country           Germany
# MIN                  3690
# Age                    24
# FS90              1.60976
# CC90              2.39024
# DR90              0.97561
# TBOX90            1.63415
# CRrat90           1.02325
# SumVal            4.58704
# SumWt             2.62019
# FS90 Rank               6
# CC90 Rank               1
# DR90 Rank              28
# TBOX90 Rank            27
# CRrat90 Rank           13
# Name: Joshua Kimmich, dtype: object

# %%
original_df.sort_values(by = 'A', ascending = False)
# Out:
#                                                                MIN     A  \
# Player                 Country        Age  Club
# Joshua Kimmich         Germany        24.0 FC Bayern        3690.0  15.0
# Trent Alexander-Arnold England        20.0 Liverpool        3296.0  15.0
# Kenny Lala             France         27.0 RC Strasbourg    2970.0   9.0
# Dani Alves             Brazil         36.0 Paris            1805.0   7.0
# Sergi Roberto          Spain          27.0 FC Barcelona     2796.0   7.0
# Jonathan Schmid        France         28.0 FC Augsburg      2610.0   7.0
# Achraf Hakimi          Morocco        20.0 Dortmund         2110.0   7.0
# Valentino Lazaro       Austria        23.0 Hertha BSC       2743.0   6.0
# Lukasz Piszczek        Poland         33.0 Dortmund         2208.0   6.0
# Ricardo Pereira        Portugal       25.0 Leicester City   3125.0   6.0
# Pol Lirola             Spain          21.0 Sassuolo         2886.0   6.0
# Daniel Brosinski       Germany        30.0 1. FSV Mainz 05  2205.0   5.0
# Kieran Trippier        England        28.0 Spurs            2814.0   5.0
# Cesar Azpilicueta      Spain          29.0 Chelsea          3403.0   5.0
# Hans Hateboer          Netherlands    25.0 Atalanta         2973.0   5.0
# Danilo D'Ambrosio      Italy          30.0 Inter            2851.0   5.0
# Joao Cancelo           Portugal       24.0 Juventus         2446.0   5.0
# Jesus Navas            Spain          33.0 Sevilla FC       2712.0   5.0
# Lars Bender            Germany        30.0 Leverkusen       1433.0   5.0
# Hector Bellerin        Spain          24.0 Arsenal          1533.0   5.0
# Leo Dubois             France         24.0 OL               2239.0   5.0
# Darijo Srna            Croatia        37.0 Cagliari         2011.0   4.0
# Hiroki Sakai           Japan          29.0 OM               2283.0   4.0
# Hugo Mallo             Spain          27.0 RC Celta         3094.0   4.0
# Jens Stryger Larsen    Denmark        28.0 Udinese          3235.0   4.0
# Pavel Kaderabek        Czech Republic 27.0 TSG Hoffenheim   3049.0   4.0
# Thomas Meunier         Belgium        27.0 Paris            1888.0   4.0
# Ruben Aguilar          France         26.0 Montpellier HSC  2441.0   4.0
# Ricardo Pereira        Portugal       25.0 Leicester City   15.0  48.0  104.0
# Pol Lirola             Spain          21.0 Sassuolo         25.0  10.0  122.0
# Daniel Brosinski       Germany        30.0 1. FSV Mainz 05  35.0  13.0  119.0
# Kieran Trippier        England        28.0 Spurs            68.0  28.0  221.0
# Cesar Azpilicueta      Spain          29.0 Chelsea          21.0  16.0  118.0
# Hans Hateboer          Netherlands    25.0 Atalanta         19.0  13.0   75.0
# Danilo D'Ambrosio      Italy          30.0 Inter            23.0  39.0   63.0
# Joao Cancelo           Portugal       24.0 Juventus         29.0  33.0  131.0
# Jesus Navas            Spain          33.0 Sevilla FC       43.0  31.0  194.0
# Lars Bender            Germany        30.0 Leverkusen        2.0  30.0   15.0
# Hector Bellerin        Spain          24.0 Arsenal           9.0   6.0   39.0
# Leo Dubois             France         24.0 OL               24.0  14.0   92.0
# Darijo Srna            Croatia        37.0 Cagliari         40.0  71.0  156.0
# Hiroki Sakai           Japan          29.0 OM                7.0  25.0   31.0
# Hugo Mallo             Spain          27.0 RC Celta         31.0  27.0  177.0
# Jens Stryger Larsen    Denmark        28.0 Udinese          20.0  14.0   79.0
# Pavel Kaderabek        Czech Republic 27.0 TSG Hoffenheim   35.0  22.0  113.0
# Thomas Meunier         Belgium        27.0 Paris            12.0   5.0   65.0
# Ruben Aguilar          France         26.0 Montpellier HSC  30.0  38.0  112.0
# Lorenzo De Silvestri   Italy          30.0 Torino           29.0  19.0  109.0
# Danny da Costa         Germany        25.0 Frankfurt        21.0  20.0  116.0
# ...                                                          ...   ...    ...
# Sebastian Rudy         Germany        29.0 Schalke           8.0  20.0   31.0
# Stephan Lichtsteiner   Switzerland    35.0 Arsenal           1.0  10.0   30.0
# Timo Baumgartl         Germany        23.0 VfB Stuttgart     2.0  12.0    5.0
# Vincent Laurini        France         29.0 Fiorentina       10.0  21.0   39.0
# Youcef Atal            Algeria        22.0 OGC Nice         10.0  58.0   70.0
# Thomas Foket           Belgium        24.0 Stade de Reims    9.0  42.0   54.0
# Edgar Ie               Portugal       25.0 FC Nantes         1.0   9.0   11.0
# Ander Capa             Spain          27.0 Athletic Club     7.0  16.0   50.0
# Jorge Miramon          Spain          29.0 SD Huesca        24.0  13.0   81.0
# Fabian Johnson         United States  31.0 M'gladbach        1.0  15.0    8.0
# Facundo Roncaglia      Argentina      32.0 Valencia CF       1.0  14.0    8.0
# Felix Eboa Eboa        Cameroon       22.0 EA Guingamp       2.0  17.0   12.0
# Florent Hadergjonaj    Switzerland    24.0 Huddersfield     23.0  19.0   91.0
# Ignazio Abate          Italy          32.0 Milan             6.0   6.0   26.0
# Javi Lopez             Spain          33.0 RCD Espanyol      9.0  35.0   57.0
# Joe Gomez              England        21.0 Liverpool         2.0  16.0   10.0
# Jonas Ramalho          Spain          25.0 Girona FC         3.0  11.0   30.0
# Danilo                 Brazil         27.0 Manchester City   7.0  75.0   21.0
# Julian Korb            Germany        27.0 Hannover 96       6.0   4.0   28.0
# Timo Baumgartl         Germany        23.0 VfB Stuttgart     841.0   2.0
# Vincent Laurini        France         29.0 Fiorentina        445.0  10.0
# Youcef Atal            Algeria        22.0 OGC Nice          944.0   9.0
# Thomas Foket           Belgium        24.0 Stade de Reims   1058.0   9.0
# Edgar Ie               Portugal       25.0 FC Nantes         423.0   1.0
# Ander Capa             Spain          27.0 Athletic Club     685.0   7.0
# Jorge Miramon          Spain          29.0 SD Huesca         983.0  24.0
# Fabian Johnson         United States  31.0 M'gladbach        504.0   1.0
# Facundo Roncaglia      Argentina      32.0 Valencia CF       806.0   1.0
# Felix Eboa Eboa        Cameroon       22.0 EA Guingamp       890.0   2.0
# Florent Hadergjonaj    Switzerland    24.0 Huddersfield      725.0  21.0
# Ignazio Abate          Italy          32.0 Milan             767.0   6.0
# Javi Lopez             Spain          33.0 RCD Espanyol      850.0   9.0
# Joe Gomez              England        21.0 Liverpool        1197.0   2.0
# Jonas Ramalho          Spain          25.0 Girona FC         716.0   3.0
# Danilo                 Brazil         27.0 Manchester City  3488.0   7.0
# Julian Korb            Germany        27.0 Hannover 96       398.0   6.0
# Antonio Barragan       Spain          31.0 Real Betis        523.0   9.0
# Cristiano Piccini      Italy          26.0 Valencia CF       867.0  13.0
# Coke                   Spain          32.0 Levante UD        746.0   8.0
# Benjamin Pavard        France         23.0 VfB Stuttgart    1444.0   7.0
# Marius Wolf            Germany        23.0 Dortmund          694.0   3.0
# Martin Kelly           England        29.0 Crystal Palace    357.0   1.0
# Michael Lang           Switzerland    28.0 M'gladbach        654.0   5.0
# Nelson Semedo          Portugal       25.0 FC Barcelona     1398.0   1.0
# Nikola Milenkovic      Serbia         21.0 Fiorentina       1581.0   3.0
# Aritz Elustondo        Spain          25.0 Real Sociedad    1108.0   9.0
# Matthew Lowton         England        29.0 Burnley           638.0   7.0
#
#                                                               CC       P  \
# Player                 Country        Age  Club
# Joshua Kimmich         Germany        24.0 FC Bayern        98.0  2709.0
# Trent Alexander-Arnold England        20.0 Liverpool        69.0  1660.0
# Kenny Lala             France         27.0 RC Strasbourg    62.0  1281.0
# Dani Alves             Brazil         36.0 Paris            35.0  1356.0
# Sergi Roberto          Spain          27.0 FC Barcelona     34.0  1922.0
# Jonathan Schmid        France         28.0 FC Augsburg      48.0   863.0
# Achraf Hakimi          Morocco        20.0 Dortmund         17.0  1445.0
# Valentino Lazaro       Austria        23.0 Hertha BSC       55.0   920.0
# Lukasz Piszczek        Poland         33.0 Dortmund         22.0  1163.0
# Ricardo Pereira        Portugal       25.0 Leicester City   33.0  1196.0
# Pol Lirola             Spain          21.0 Sassuolo         40.0  1068.0
# Daniel Brosinski       Germany        30.0 1. FSV Mainz 05  40.0   698.0
# Kieran Trippier        England        28.0 Spurs            72.0  1465.0
# Cesar Azpilicueta      Spain          29.0 Chelsea          27.0  2160.0
# Hans Hateboer          Netherlands    25.0 Atalanta         48.0  1334.0
# Danilo D'Ambrosio      Italy          30.0 Inter            38.0  1512.0
# Joao Cancelo           Portugal       24.0 Juventus         42.0  1282.0
# Jesus Navas            Spain          33.0 Sevilla FC       42.0  1092.0
# Lars Bender            Germany        30.0 Leverkusen       17.0   730.0
# Hector Bellerin        Spain          24.0 Arsenal           8.0   660.0
# Leo Dubois             France         24.0 OL               26.0  1094.0
# Darijo Srna            Croatia        37.0 Cagliari         42.0   963.0
# Hiroki Sakai           Japan          29.0 OM               25.0   923.0
# Hugo Mallo             Spain          27.0 RC Celta         31.0  1112.0
# Jens Stryger Larsen    Denmark        28.0 Udinese          31.0  1129.0
# Pavel Kaderabek        Czech Republic 27.0 TSG Hoffenheim   53.0  1004.0
# Thomas Meunier         Belgium        27.0 Paris            21.0   817.0
# Ruben Aguilar          France         26.0 Montpellier HSC  43.0   992.0
# Lorenzo De Silvestri   Italy          30.0 Torino           28.0   557.0
# Danny da Costa         Germany        25.0 Frankfurt        33.0   582.0
# ...                                                          ...     ...
# Sebastian Rudy         Germany        29.0 Schalke          19.0   644.0
# Stephan Lichtsteiner   Switzerland    35.0 Arsenal           3.0   377.0
# Timo Baumgartl         Germany        23.0 VfB Stuttgart     5.0   689.0
# Vincent Laurini        France         29.0 Fiorentina        7.0   355.0
# Youcef Atal            Algeria        22.0 OGC Nice         22.0   783.0
# Thomas Foket           Belgium        24.0 Stade de Reims   13.0   811.0
# Edgar Ie               Portugal       25.0 FC Nantes         2.0   336.0
# Ander Capa             Spain          27.0 Athletic Club    12.0   505.0
# Jorge Miramon          Spain          29.0 SD Huesca        26.0   738.0
# Fabian Johnson         United States  31.0 M'gladbach        4.0   404.0
# Facundo Roncaglia      Argentina      32.0 Valencia CF       2.0   667.0
# Felix Eboa Eboa        Cameroon       22.0 EA Guingamp       5.0   687.0
# Florent Hadergjonaj    Switzerland    24.0 Huddersfield     23.0   545.0
# Ignazio Abate          Italy          32.0 Milan             7.0   645.0
# Javi Lopez             Spain          33.0 RCD Espanyol     17.0   664.0
# Joe Gomez              England        21.0 Liverpool         9.0  1030.0
# Jonas Ramalho          Spain          25.0 Girona FC         2.0   602.0
# Danilo                 Brazil         27.0 Manchester City  31.0  2901.0
# Julian Korb            Germany        27.0 Hannover 96      10.0   283.0
# Antonio Barragan       Spain          31.0 Real Betis        9.0   450.0
# Cristiano Piccini      Italy          26.0 Valencia CF       7.0   670.0
# Coke                   Spain          32.0 Levante UD       12.0   558.0
# Benjamin Pavard        France         23.0 VfB Stuttgart    11.0  1221.0
# Marius Wolf            Germany        23.0 Dortmund         11.0   579.0
# Martin Kelly           England        29.0 Crystal Palace    1.0   269.0
# Michael Lang           Switzerland    28.0 M'gladbach        4.0   547.0
# Nelson Semedo          Portugal       25.0 FC Barcelona      8.0  1274.0
# Nikola Milenkovic      Serbia         21.0 Fiorentina        3.0  1259.0
# Aritz Elustondo        Spain          25.0 Real Sociedad     9.0   874.0
# Matthew Lowton         England        29.0 Burnley           8.0   440.0
#
#                                                               DR  TBOX  \
# Player                 Country        Age  Club
# Joshua Kimmich         Germany        24.0 FC Bayern        40.0  67.0
# Trent Alexander-Arnold England        20.0 Liverpool        21.0  54.0
# Kenny Lala             France         27.0 RC Strasbourg    35.0  27.0
# Dani Alves             Brazil         36.0 Paris            18.0  42.0
# Sergi Roberto          Spain          27.0 FC Barcelona     21.0  78.0
# Jonathan Schmid        France         28.0 FC Augsburg      16.0  18.0
# Achraf Hakimi          Morocco        20.0 Dortmund         43.0  45.0
# Valentino Lazaro       Austria        23.0 Hertha BSC       34.0  45.0
# Lukasz Piszczek        Poland         33.0 Dortmund          9.0  34.0
# Ricardo Pereira        Portugal       25.0 Leicester City   68.0  79.0
# Pol Lirola             Spain          21.0 Sassuolo         40.0  62.0
# Daniel Brosinski       Germany        30.0 1. FSV Mainz 05   6.0  18.0
# Kieran Trippier        England        28.0 Spurs             9.0  35.0
# Cesar Azpilicueta      Spain          29.0 Chelsea          10.0  50.0
# Hans Hateboer          Netherlands    25.0 Atalanta         14.0  96.0
# Danilo D'Ambrosio      Italy          30.0 Inter            15.0  58.0
# Joao Cancelo           Portugal       24.0 Juventus         71.0  57.0
# Jesus Navas            Spain          33.0 Sevilla FC       34.0  86.0
# Lars Bender            Germany        30.0 Leverkusen       12.0  42.0
# Hector Bellerin        Spain          24.0 Arsenal          14.0  53.0
# Leo Dubois             France         24.0 OL               13.0  44.0
# Darijo Srna            Croatia        37.0 Cagliari         11.0   4.0
# Hiroki Sakai           Japan          29.0 OM               12.0  27.0
# Hugo Mallo             Spain          27.0 RC Celta         22.0  54.0
# Jens Stryger Larsen    Denmark        28.0 Udinese          11.0  25.0
# Pavel Kaderabek        Czech Republic 27.0 TSG Hoffenheim    9.0  80.0
# Thomas Meunier         Belgium        27.0 Paris             9.0  64.0
# Ruben Aguilar          France         26.0 Montpellier HSC  36.0  34.0
# Lorenzo De Silvestri   Italy          30.0 Torino            4.0  66.0
# Danny da Costa         Germany        25.0 Frankfurt        29.0  60.0
# ...                                                          ...   ...
# Sebastian Rudy         Germany        29.0 Schalke           8.0  15.0
# Stephan Lichtsteiner   Switzerland    35.0 Arsenal           4.0  11.0
# Timo Baumgartl         Germany        23.0 VfB Stuttgart     4.0  13.0
# Vincent Laurini        France         29.0 Fiorentina       11.0   1.0
# Youcef Atal            Algeria        22.0 OGC Nice         96.0  95.0
# Thomas Foket           Belgium        24.0 Stade de Reims   11.0  19.0
# Edgar Ie               Portugal       25.0 FC Nantes         8.0   5.0
# Ander Capa             Spain          27.0 Athletic Club    20.0  36.0
# Jorge Miramon          Spain          29.0 SD Huesca        34.0  18.0
# Fabian Johnson         United States  31.0 M'gladbach        1.0  17.0
# Facundo Roncaglia      Argentina      32.0 Valencia CF       3.0  11.0
# Felix Eboa Eboa        Cameroon       22.0 EA Guingamp       8.0  24.0
# Florent Hadergjonaj    Switzerland    24.0 Huddersfield     10.0  12.0
# Ignazio Abate          Italy          32.0 Milan             4.0  11.0
# Leo Dubois             France         24.0 OL               85.602504
# Darijo Srna            Croatia        37.0 Cagliari         81.610169
# Hiroki Sakai           Japan          29.0 OM               81.971581
# Hugo Mallo             Spain          27.0 RC Celta         74.580818
# Jens Stryger Larsen    Denmark        28.0 Udinese          79.675371
# Pavel Kaderabek        Czech Republic 27.0 TSG Hoffenheim   76.875957
# Thomas Meunier         Belgium        27.0 Paris            83.709016
# Ruben Aguilar          France         26.0 Montpellier HSC  83.082077
# Lorenzo De Silvestri   Italy          30.0 Torino           67.597087
# Danny da Costa         Germany        25.0 Frankfurt        62.648009
# ...                                                               ...
# Sebastian Rudy         Germany        29.0 Schalke          80.500000
# Stephan Lichtsteiner   Switzerland    35.0 Arsenal          78.541667
# Timo Baumgartl         Germany        23.0 VfB Stuttgart    81.926278
# Vincent Laurini        France         29.0 Fiorentina       79.775281
# Youcef Atal            Algeria        22.0 OGC Nice         82.944915
# Thomas Foket           Belgium        24.0 Stade de Reims   76.654064
# Edgar Ie               Portugal       25.0 FC Nantes        79.432624
# Ander Capa             Spain          27.0 Athletic Club    73.722628
# Jorge Miramon          Spain          29.0 SD Huesca        75.076297
# Fabian Johnson         United States  31.0 M'gladbach       80.158730
# Facundo Roncaglia      Argentina      32.0 Valencia CF      82.754342
# Felix Eboa Eboa        Cameroon       22.0 EA Guingamp      77.191011
# Florent Hadergjonaj    Switzerland    24.0 Huddersfield     75.172414
# Ignazio Abate          Italy          32.0 Milan            84.093872
# Javi Lopez             Spain          33.0 RCD Espanyol     78.117647
# Joe Gomez              England        21.0 Liverpool        86.048454
# Jonas Ramalho          Spain          25.0 Girona FC        84.078212
# Danilo                 Brazil         27.0 Manchester City  83.170872
# Julian Korb            Germany        27.0 Hannover 96      71.105528
# Antonio Barragan       Spain          31.0 Real Betis       86.042065
# Cristiano Piccini      Italy          26.0 Valencia CF      77.277970
# Coke                   Spain          32.0 Levante UD       74.798928
# Benjamin Pavard        France         23.0 VfB Stuttgart    84.556787
# Marius Wolf            Germany        23.0 Dortmund         83.429395
# Martin Kelly           England        29.0 Crystal Palace   75.350140
# Michael Lang           Switzerland    28.0 M'gladbach       83.639144
# Nelson Semedo          Portugal       25.0 FC Barcelona     91.130186
# Nikola Milenkovic      Serbia         21.0 Fiorentina       79.633144
# Aritz Elustondo        Spain          25.0 Real Sociedad    78.880866
# Matthew Lowton         England        29.0 Burnley          68.965517
#
# [132 rows x 13 columns]

# %% [markdown]
# ### Best U23 Prospects

# %%
logic = (df['MIN'] > 900) & (df['Age'] < 24.0)
xdf = df[logic].sort_values(by = 'SumVal', ascending = False)


pdf = xdf.iloc[:20]
pdf = pdf.drop(130, axis = 'index')
pdf = pdf.drop(72, axis = 'index')

# %%
pdf
# Out:
#                      Player            Club      Country     MIN   Age  \
# 6          Alvaro Odriozola     Real Madrid        Spain  1406.0  23.0
# 69               Kenny Tete              OL  Netherlands  1246.0  23.0
# 122  Trent Alexander-Arnold       Liverpool      England  3296.0  20.0
# 1             Achraf Hakimi        Dortmund      Morocco  2110.0  20.0
# 119        Timothy Castagne        Atalanta      Belgium  1911.0  23.0
# 125        Valentino Lazaro      Hertha BSC      Austria  2743.0  23.0
# 37              Diogo Dalot  Manchester Utd     Portugal  1257.0  20.0
# 14        Benjamin Henrichs       AS Monaco      Germany  2097.0  22.0
# 94                 Ola Aina          Torino      Nigeria  2067.0  22.0
# 81              Marius Wolf        Dortmund      Germany  1042.0  23.0
# 97               Pol Lirola        Sassuolo        Spain  2886.0  21.0
# 93            Nordi Mukiele      RB Leipzig       France  1226.0  21.0
# 78        Lukas Klostermann      RB Leipzig      Germany  2001.0  22.0
# 111           Simon Francis      Real Betis        Spain  1227.0  23.0
# 0         Aaron Wan-Bissaka  Crystal Palace      England  3135.0  21.0
# 124         Valentin Rosier       Dijon FCO       France  1458.0  22.0
# 33          Davide Calabria           Milan        Italy  1953.0  22.0
# 5              Almamy Toure       Frankfurt         Mali   971.0  23.0
#
#          FS90      CC90      DR90    TBOX90   CRrat90    SumVal     SumWt
# 6    1.344239  1.344239  0.576102  3.520626  0.618167  4.724676  2.298110
# 69   1.011236  1.516854  0.216693  2.166934  1.450288  3.420707  2.200283
# 122  0.273058  1.884102  0.573422  1.474515  1.629727  3.320422  2.114960
# 1    1.876777  0.725118  1.834123  1.919431  0.198535  3.126722  1.930242
# 119  0.659341  1.224490  0.894819  2.731554  0.493221  2.967695  1.856816
# 125  0.918702  1.804594  1.115567  1.476486  0.808492  2.784007  2.057646
# 37   0.143198  1.288783  1.145585  1.646778  1.461814  2.666766  1.938121
# 14   2.060086  0.987124  0.557940  1.630901  0.527507  2.620207  1.849411
# 94   1.611030  0.957910  1.306241  1.523948  0.755701  2.472240  1.957871
# 81   1.295585  0.950096  1.209213  1.986564  0.178317  2.289482  1.692520
# 97   0.311850  1.247401  1.247401  1.933472  0.639038  2.202786  1.707615
# 93   1.541599  0.807504  1.394780  1.174551  0.587276  2.012702  1.731979
# 78   0.494753  0.899550  0.314843  1.844078  0.287856  1.340685  1.206979
# 111  0.586797  0.733496  0.366748  0.953545  1.109413  1.143609  1.317505
# 0    0.459330  0.401914  1.751196  0.861244  0.295284  1.131541  1.102286
# 124  1.172840  0.679012  0.987654  0.802469  0.448102  1.123404  1.303711
# 33   0.829493  0.921659  0.552995  0.921659  0.555831  1.001381  1.265963
# 5    0.278064  0.278064  1.575695  0.648816  0.333677  0.836781  0.912402

# %%
sns.set()

sns.set_palette('Blues_d')

ax = pdf.plot.barh('Player', 'SumVal', figsize = (20, 12))
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
ax.set_xlabel('Attacking Output', fontsize = 14, family = 'Impact')
ax.set_ylabel('Player', fontsize = 14, family = 'Impact')
ax.set_title('Best Offensive Right Backs (Under 23) in Top 5 Leagues (Minimum 900 Minutes)', family = 'Impact', fontsize = 19)

# %%
plt.gcf().savefig('rbu23.jpg', dpi = 500)

# %%
ax.legend('')

# %%
a
